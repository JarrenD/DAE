# %%
import pandas as pd

data = pd.read_csv("../gorilla_tug_of_war.csv")
data.info()

# %% [markdown]
# No none values
# Hot encode SUS and GND

# %%
data.describe()
# Out:
#               WHT         FRC         AGE          DSI        HMNS
# count  500.000000  500.000000  500.000000   500.000000  500.000000
# mean   178.423200  112.752000   24.446000   211.622000  202.372000
# std     43.545844   28.490242    9.391458   196.069706   29.509715
# min     93.900000   37.000000   -4.000000     1.000000   88.000000
# 25%    150.800000   94.000000   16.000000    74.750000  188.750000
# 50%    175.050000  112.000000   25.000000   151.500000  212.000000
# 75%    202.625000  131.250000   32.000000   285.500000  223.000000
# max    765.900000  203.000000   40.000000  1095.000000  249.000000

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# No Duplicates

# %%
data['HMNS'].corr(data['WHT'])
# Out:
# np.float64(0.6126892034993202)

# %%
data['HMNS'].corr(data['AGE'])
# Out:
# np.float64(0.020044791500679913)

# %%
data['HMNS'].corr(data['FRC'])
# Out:
# np.float64(0.5053673793515394)

# %%
data['HMNS'].corr(data['DSI'])
# Out:
# np.float64(0.014121427129516058)

# %%
data["SUS"].value_counts()
# Out:
# SUS
# Mountain           149
# Western Lowland    134
# Cross River        110
# Grauer's           107
# Name: count, dtype: int64

# %%
data["GND"].value_counts()
# Out:
# GND
# Male      258
# Female    242
# Name: count, dtype: int64

# %%
data[['WHT', 'AGE', 'DSI', 'FRC']].hist(bins=20, figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': 'WHT'}>, <Axes: title={'center': 'AGE'}>],
#        [<Axes: title={'center': 'DSI'}>, <Axes: title={'center': 'FRC'}>]],
#       dtype=object)

# %%
data.corr(numeric_only=True)

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(x='WHT', y='HMNS', data=data)
# Out:
# <Axes: xlabel='WHT', ylabel='HMNS'>

# %%
sns.scatterplot(x='AGE', y='HMNS', data=data)
# Out:
# <Axes: xlabel='AGE', ylabel='HMNS'>

# %%
sns.scatterplot(x='FRC', y='HMNS', data=data)
# Out:
# <Axes: xlabel='FRC', ylabel='HMNS'>

# %%
sns.scatterplot(x='DSI', y='HMNS', data=data)
# Out:
# <Axes: xlabel='DSI', ylabel='HMNS'>

# %%
sns.boxplot(x='SUS', y='HMNS', data=data)
# Out:
# <Axes: xlabel='SUS', ylabel='HMNS'>

# %%
sns.boxplot(x='GND', y='HMNS', data=data)
# Out:
# <Axes: xlabel='GND', ylabel='HMNS'>

# %%
count_negative_ages = (data['AGE'] < 0).sum()
print(count_negative_ages)
# Out:
# 1
